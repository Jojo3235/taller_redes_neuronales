# %%
# 2. Explore the dataset
import os
from PIL import Image

# %%
# Define the directory where the dataset is
base_dir = "test"

# Load the name of all the folders
class_folders = [folder for folder in os.listdir(base_dir)]

# Load the images
images_dict = {}
for class_folder in class_folders:
    class_path = os.path.join(base_dir, class_folder)
    image_files = [image_file for image_file in os.listdir(class_path)]

    images_dict[class_folder] = []
    for image_file in image_files:
        image_path = os.path.join(class_path, image_file)
        with Image.open(image_path) as img:
            images_dict[class_folder].append(img.copy())

# Explore numbers on my dataset
print(f"We have a total of: {len(images_dict)} classes (also called labels)")
for key, value in images_dict.items():
    print(f"    - We have {len(value)} of the class '{key}'")
    # Print all the sizes that we have in each class
    size_count_dict = {}
    for image in value:
        size = image.size
        # Get the value (in this case the number of repetitions of the key)
        # size (tuple with the size of the image) and change it for its value
        # plus one. If there were no repetitions yet, get 0 and add 1
        size_count_dict[size] = size_count_dict.get(size, 0) +1
    for size, count in size_count_dict.items():
        print(f"{count} image(s) of size {size}")
# Out:
# We have a total of: 8 classes (also called labels)
#     - We have 108 of the class 'buen comestible'
# 1 image(s) of size (936, 624)
# 1 image(s) of size (1024, 768)
# 1 image(s) of size (801, 600)
# 1 image(s) of size (800, 600)
# 36 image(s) of size (259, 194)
# 3 image(s) of size (267, 189)
# 16 image(s) of size (275, 183)
# 1 image(s) of size (258, 195)
# 2 image(s) of size (183, 275)
# 2 image(s) of size (273, 184)
# 4 image(s) of size (276, 183)
# 5 image(s) of size (300, 168)
# 1 image(s) of size (250, 187)
# 1 image(s) of size (201, 251)
# 5 image(s) of size (225, 225)
# 1 image(s) of size (293, 172)
# 1 image(s) of size (247, 204)
# 1 image(s) of size (250, 188)
# 1 image(s) of size (261, 193)
# 1 image(s) of size (306, 165)
# 1 image(s) of size (334, 151)
# 1 image(s) of size (211, 239)
# 3 image(s) of size (194, 259)
# 1 image(s) of size (268, 188)
# 1 image(s) of size (294, 171)
# 1 image(s) of size (232, 217)
# 1 image(s) of size (264, 191)
# 1 image(s) of size (304, 166)
# 1 image(s) of size (269, 188)
# 2 image(s) of size (265, 190)
# 1 image(s) of size (280, 180)
# 1 image(s) of size (277, 182)
# 1 image(s) of size (272, 186)
# 1 image(s) of size (274, 184)
# 1 image(s) of size (279, 180)
# 1 image(s) of size (286, 176)
# 1 image(s) of size (266, 190)
# 1 image(s) of size (273, 185)
# 1 image(s) of size (292, 173)
# 1 image(s) of size (270, 187)
#     - We have 103 of the class 'comestible'
# 1 image(s) of size (645, 442)
# 1 image(s) of size (866, 650)
# 44 image(s) of size (250, 188)
# 1 image(s) of size (265, 190)
# 4 image(s) of size (275, 183)
# 17 image(s) of size (259, 194)
# 2 image(s) of size (225, 225)
# 1 image(s) of size (301, 168)
# 2 image(s) of size (272, 185)
# 1 image(s) of size (276, 182)
# 1 image(s) of size (212, 238)
# 1 image(s) of size (253, 199)
# 1 image(s) of size (250, 202)
# 1 image(s) of size (259, 195)
# 1 image(s) of size (250, 187)
# 1 image(s) of size (270, 187)
# 2 image(s) of size (273, 185)
# 1 image(s) of size (273, 184)
# 1 image(s) of size (281, 179)
# 1 image(s) of size (267, 189)
# 1 image(s) of size (260, 194)
# 1 image(s) of size (301, 167)
# 16 image(s) of size (140, 105)
#     - We have 94 of the class 'comestible precaucion'
# 16 image(s) of size (250, 188)
# 28 image(s) of size (259, 194)
# 2 image(s) of size (270, 186)
# 1 image(s) of size (176, 287)
# 1 image(s) of size (274, 184)
# 2 image(s) of size (194, 259)
# 1 image(s) of size (239, 211)
# 16 image(s) of size (275, 183)
# 1 image(s) of size (250, 187)
# 2 image(s) of size (255, 198)
# 1 image(s) of size (271, 186)
# 1 image(s) of size (266, 190)
# 4 image(s) of size (276, 183)
# 1 image(s) of size (269, 187)
# 1 image(s) of size (278, 182)
# 1 image(s) of size (236, 214)
# 1 image(s) of size (198, 254)
# 1 image(s) of size (193, 261)
# 1 image(s) of size (295, 171)
# 1 image(s) of size (268, 188)
# 1 image(s) of size (296, 170)
# 1 image(s) of size (260, 194)
# 1 image(s) of size (217, 232)
# 1 image(s) of size (301, 167)
# 1 image(s) of size (286, 176)
# 1 image(s) of size (191, 263)
# 1 image(s) of size (183, 275)
# 1 image(s) of size (267, 188)
# 3 image(s) of size (140, 105)
#     - We have 108 of the class 'excelente comestible'
# 15 image(s) of size (250, 188)
# 9 image(s) of size (140, 105)
# 2 image(s) of size (270, 187)
# 32 image(s) of size (259, 194)
# 1 image(s) of size (257, 196)
# 1 image(s) of size (213, 237)
# 3 image(s) of size (274, 184)
# 1 image(s) of size (197, 256)
# 2 image(s) of size (277, 182)
# 1 image(s) of size (255, 197)
# 1 image(s) of size (255, 198)
# 4 image(s) of size (300, 168)
# 2 image(s) of size (276, 183)
# 1 image(s) of size (272, 185)
# 1 image(s) of size (271, 186)
# 2 image(s) of size (273, 185)
# 1 image(s) of size (357, 141)
# 13 image(s) of size (275, 183)
# 1 image(s) of size (290, 174)
# 1 image(s) of size (298, 169)
# 1 image(s) of size (299, 168)
# 1 image(s) of size (282, 179)
# 1 image(s) of size (284, 177)
# 3 image(s) of size (261, 193)
# 1 image(s) of size (220, 229)
# 1 image(s) of size (268, 188)
# 1 image(s) of size (266, 189)
# 1 image(s) of size (239, 211)
# 1 image(s) of size (288, 175)
# 1 image(s) of size (307, 164)
# 1 image(s) of size (308, 164)
# 1 image(s) of size (256, 197)
#     - We have 91 of the class 'mortal'
# 6 image(s) of size (250, 188)
# 1 image(s) of size (190, 265)
# 21 image(s) of size (259, 194)
# 1 image(s) of size (245, 205)
# 9 image(s) of size (194, 259)
# 2 image(s) of size (274, 184)
# 12 image(s) of size (275, 183)
# 2 image(s) of size (276, 183)
# 1 image(s) of size (280, 180)
# 1 image(s) of size (263, 192)
# 1 image(s) of size (258, 195)
# 1 image(s) of size (200, 251)
# 3 image(s) of size (183, 275)
# 1 image(s) of size (294, 171)
# 2 image(s) of size (251, 201)
# 2 image(s) of size (283, 178)
# 1 image(s) of size (301, 167)
# 1 image(s) of size (272, 185)
# 1 image(s) of size (259, 195)
# 1 image(s) of size (299, 168)
# 2 image(s) of size (269, 187)
# 1 image(s) of size (287, 175)
# 4 image(s) of size (300, 168)
# 1 image(s) of size (269, 188)
# 2 image(s) of size (262, 193)
# 1 image(s) of size (201, 251)
# 1 image(s) of size (282, 178)
# 1 image(s) of size (225, 224)
# 1 image(s) of size (278, 181)
# 1 image(s) of size (277, 182)
# 1 image(s) of size (285, 177)
# 1 image(s) of size (288, 175)
# 1 image(s) of size (256, 197)
# 1 image(s) of size (250, 201)
# 2 image(s) of size (140, 105)
#     - We have 77 of the class 'No comestible'
# 58 image(s) of size (250, 188)
# 18 image(s) of size (140, 105)
# 1 image(s) of size (250, 333)
#     - We have 90 of the class 'sin valor'
# 70 image(s) of size (250, 188)
# 20 image(s) of size (140, 105)
#     - We have 102 of the class 'toxica'
# 15 image(s) of size (250, 188)
# 2 image(s) of size (300, 216)
# 5 image(s) of size (276, 183)
# 3 image(s) of size (300, 168)
# 15 image(s) of size (275, 183)
# 1 image(s) of size (261, 193)
# 2 image(s) of size (272, 186)
# 25 image(s) of size (259, 194)
# 1 image(s) of size (267, 189)
# 1 image(s) of size (183, 275)
# 2 image(s) of size (268, 188)
# 1 image(s) of size (265, 191)
# 1 image(s) of size (200, 252)
# 1 image(s) of size (206, 245)
# 1 image(s) of size (194, 260)
# 1 image(s) of size (272, 185)
# 3 image(s) of size (194, 259)
# 1 image(s) of size (255, 197)
# 1 image(s) of size (274, 184)
# 1 image(s) of size (266, 189)
# 1 image(s) of size (250, 166)
# 1 image(s) of size (249, 203)
# 2 image(s) of size (265, 190)
# 1 image(s) of size (212, 238)
# 1 image(s) of size (273, 184)
# 1 image(s) of size (242, 208)
# 1 image(s) of size (217, 232)
# 1 image(s) of size (254, 199)
# 1 image(s) of size (192, 262)
# 1 image(s) of size (260, 194)
# 1 image(s) of size (269, 187)
# 1 image(s) of size (188, 269)
# 1 image(s) of size (250, 202)
# 1 image(s) of size (263, 192)
# 1 image(s) of size (256, 197)
# 1 image(s) of size (195, 258)
# 2 image(s) of size (271, 186)

# %%
keys = images_dict.keys()

for key in keys:
  print(key,len(images_dict[key]))
# Out:
# buen comestible 108
# comestible 103
# comestible precaucion 94
# excelente comestible 108
# mortal 91
# No comestible 77
# sin valor 90
# toxica 102

# %%
# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tensorflow.keras.utils import to_categorical
import numpy as np

# Resize to 200 by 200
TARGET_SIZE = (200, 200)

for class_folder in images_dict:
    resized_images = []
    for img in images_dict[class_folder]:
        # Redimensionar con antialiasing para mejor calidad
        img_resized = img.resize(TARGET_SIZE, Image.Resampling.LANCZOS)
        resized_images.append(img_resized)
    images_dict[class_folder] = resized_images


# Split our dataset
test_dict = {}
train_val_dict = {}
for class_name, images in images_dict.items():
    train_val_images, test_images = train_test_split(images, test_size=0.2)
    train_val_dict[class_name] = train_val_images
    test_dict[class_name] = test_images

train_dict = {}
val_dict = {}
for class_name, images in train_val_dict.items():
    train_images, val_images = train_test_split(images, test_size = 0.2)
    val_dict[class_name] = val_images
    train_dict[class_name] = train_images

# Split features and labels
x_train = []
y_train = []
x_val = []
y_val = []
x_test = []
y_test = []

for class_name in train_dict:
    x_train.extend(train_dict[class_name])
    y_train.extend([class_name]*len(train_dict[class_name]))

for class_name in val_dict:
    x_val.extend(val_dict[class_name])
    y_val.extend([class_name]*len(val_dict[class_name]))

for class_name in test_dict:
    x_test.extend(test_dict[class_name])
    y_test.extend([class_name]*len(test_dict[class_name]))

# Convert to np.array
X_train = [np.array(img, dtype= "float32") for img in x_train]
X_val = [np.array(img, dtype= "float32") for img in x_val]
X_test = [np.array(img, dtype= "float32") for img in x_test]

# Normalize
max_value = np.max(X_train)
X_train = [img/max_value for img in X_train]
X_val = [img/max_value for img in X_val]
X_test = [img/max_value for img in X_test]


# Convert the list of np.arrays to a np.array
X_train = np.stack(X_train)
X_val = np.stack(X_val)
X_test = np.stack(X_test)


# Convert the labels with encoding
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)   # Only fit_transform the first one
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# One-hot enconding/categorical
num_classes = len(label_encoder.classes_)
y_train = to_categorical(y_train, num_classes=num_classes)
y_val = to_categorical(y_val, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# %%
# Sometimes this won't be necessary or ideal

# Reduce to greyscale
X_train = np.mean(X_train, axis=3, keepdims=True)
X_val = np.mean(X_val, axis=3, keepdims=True)
X_test = np.mean(X_test, axis=3, keepdims=True)

# Reduce the number of features (img size)
def avg_pooling(X,pool_size = 2):
    num_samples, height, width, channels = X.shape
    new_height, new_width = height//pool_size, width//pool_size

    X_reshape = X.reshape(num_samples, new_height, pool_size, new_width, pool_size, channels)

    X_pooled = np.mean(X_reshape, axis=(2,4), keepdims=True)

    return X_pooled.reshape(num_samples, new_height, new_width, channels)

# Apply to all datasets
# X_train = avg_pooling(X_train)
# X_val = avg_pooling(X_val)
# X_test = avg_pooling(X_test)

# %%
# Data augmentation
X_train_flipped = np.flip(X_train, axis=2)
X_train = np.concatenate([X_train, X_train_flipped], axis=0)
y_train = np.concatenate([y_train, y_train], axis=0)
X_train_flipped = np.flip(X_train, axis=1)
X_train = np.concatenate([X_train, X_train_flipped], axis=0)
y_train = np.concatenate([y_train, y_train], axis=0)

# %%
# Define our model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Add, Conv2D, BatchNormalization, MaxPooling2D, Dropout, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def build_model(input_shape, num_classes):

    """
    Build classifier model

    This model builds a classifier for the images tha we pass of the clouds from the dataverse dataset.

    Args:
        input_shape(int): shape of images
        num_classes(int): number of classes

    Returns:
        model (tensorflow.keras.model): my model
    """

    def conv_block(x, filters):
        """
        Convolutional block

        This block will contain my convolutional layers for the example of the clouds,
        since we already now regularization, I will use regularization here as well.

        Args:
            x (tensor): Tensorflow tensor
            filters (int): filters in my layers

        Returns:
            x (tensor): Tensorflow tensor
        """
        
        x1 = Conv2D(filters, [3,3], padding='same', use_bias=False)(x)
        x1 = BatchNormalization()(x1)
        x1 = Activation("relu")(x1)

        x2 = Conv2D(filters, [3,3], padding='same', use_bias=False)(x1)
        x2 = BatchNormalization()(x2)
        x2 = Activation("relu")(x2)


        x3 = Conv2D(filters, [3,3], padding='same', use_bias=False)(x2)
        x3 = BatchNormalization()(x3)
        x3 = Activation("relu")(x3)

        x_add = Add()([x3, x1])

        x_output = BatchNormalization()(x_add)


        x = MaxPooling2D(pool_size = (5,5), padding='same')(x_output) # Aseguramos padding='same' para mantener la estructura ResNet-like
        x = Dropout(0.3 if filters > 32 else 0.1)(x)

        return x

    def mlp_block(x, units, last):
        """
        Create the MLP block.

        This is the block that classifies the images from the preprocessing done by the
        convolutional layers to transform the dog and cat to something more understandable for the mlp.

        Args:
            x (tensor): Tensorflow tensor
            units (int): number of nuerons
            last (bool): Tells if we are building the last block

        Returns:
            x (tensor): Tensorflow tensor
        """

        x = Dense(units, activation="relu",kernel_regularizer=l2(0.01))(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

        if not last:
            x = Dropout(0.2)(x)

        return x


    inputs = Input(shape=input_shape)
    x = conv_block(inputs,32)
    x = conv_block(x,8)
    x = conv_block(x,8)
    x = conv_block(x,32)

    x = GlobalAveragePooling2D()(x) #Flatten() in an alternative way

    x1 = mlp_block(x,512,False)
    x = mlp_block(x,128,False)
    x2 = mlp_block(x,512,False)
    x_add = Add()([x1,x2])
    x = mlp_block(x_add,256,True)
    x = mlp_block(x_add,128 ,True)
    x = mlp_block(x,16,True)

    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs= inputs, outputs= outputs)

    return model

# %%
# Training
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


patience = 20

input_shape = X_train.shape[1:]

class_dim = y_train.shape[1]

model = build_model(input_shape, class_dim)
model.compile(optimizer = "adam", loss ="categorical_crossentropy", metrics = ["accuracy"])


reduce_lr = ReduceLROnPlateau(monitor= "val_loss", factor=0.5, patience=patience, min_lr = 1e-5, verbose = 1)
early_stopping = EarlyStopping(monitor= "val_loss", patience= patience, restore_best_weights= True)
history = model.fit(
    x=X_train, y = y_train,
    validation_data = (X_val, y_val),
    epochs = 1000,
    batch_size = 8,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/1000
# 244/244 [==============================] - 25s 87ms/step - loss: 7.2759 - accuracy: 0.1443 - val_loss: 6.8619 - val_accuracy: 0.1172 - lr: 0.0010
# Epoch 2/1000
# 244/244 [==============================] - 21s 86ms/step - loss: 6.4612 - accuracy: 0.1371 - val_loss: 6.5495 - val_accuracy: 0.1250 - lr: 0.0010
# Epoch 3/1000
# 244/244 [==============================] - 22s 88ms/step - loss: 5.7009 - accuracy: 0.1622 - val_loss: 5.5460 - val_accuracy: 0.1484 - lr: 0.0010
# Epoch 4/1000
# 244/244 [==============================] - 22s 89ms/step - loss: 4.9682 - accuracy: 0.1715 - val_loss: 4.6966 - val_accuracy: 0.1484 - lr: 0.0010
# Epoch 5/1000
# 244/244 [==============================] - 22s 88ms/step - loss: 4.3389 - accuracy: 0.1751 - val_loss: 4.1414 - val_accuracy: 0.1797 - lr: 0.0010
# Epoch 6/1000
# 244/244 [==============================] - 21s 86ms/step - loss: 3.8025 - accuracy: 0.1771 - val_loss: 3.6458 - val_accuracy: 0.1562 - lr: 0.0010
# Epoch 7/1000
# 244/244 [==============================] - 21s 86ms/step - loss: 3.3822 - accuracy: 0.1786 - val_loss: 3.3034 - val_accuracy: 0.1719 - lr: 0.0010
# Epoch 8/1000
# 244/244 [==============================] - 22s 90ms/step - loss: 3.0395 - accuracy: 0.1761 - val_loss: 3.0220 - val_accuracy: 0.1719 - lr: 0.0010
# Epoch 9/1000
# 244/244 [==============================] - 23s 93ms/step - loss: 2.7897 - accuracy: 0.1802 - val_loss: 2.7457 - val_accuracy: 0.1797 - lr: 0.0010
# Epoch 10/1000
# 244/244 [==============================] - 23s 95ms/step - loss: 2.5887 - accuracy: 0.1905 - val_loss: 2.6401 - val_accuracy: 0.1250 - lr: 0.0010
# Epoch 11/1000
1000
# 244/244 [==============================] - 21s 85ms/step - loss: 1.6326 - accuracy: 0.3475 - val_loss: 1.8695 - val_accuracy: 0.2422 - lr: 0.0010
# Epoch 92/1000
# 244/244 [==============================] - 21s 85ms/step - loss: 1.6343 - accuracy: 0.3403 - val_loss: 1.9076 - val_accuracy: 0.1953 - lr: 0.0010
# Epoch 93/1000
# 244/244 [==============================] - 21s 86ms/step - loss: 1.6054 - accuracy: 0.3557 - val_loss: 1.9870 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 94/1000
# 244/244 [==============================] - 20s 84ms/step - loss: 1.6063 - accuracy: 0.3573 - val_loss: 1.8456 - val_accuracy: 0.2422 - lr: 0.0010
# Epoch 95/1000
# 244/244 [==============================] - 21s 85ms/step - loss: 1.5832 - accuracy: 0.3573 - val_loss: 1.8162 - val_accuracy: 0.2656 - lr: 0.0010
# Epoch 96/1000
# 244/244 [==============================] - 21s 85ms/step - loss: 1.5706 - accuracy: 0.3552 - val_loss: 2.0091 - val_accuracy: 0.2109 - lr: 0.0010
# Epoch 97/1000
# 243/244 [============================>.] - ETA: 0s - loss: 1.5603 - accuracy: 0.3735
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 244/244 [==============================] - 21s 86ms/step - loss: 1.5608 - accuracy: 0.3732 - val_loss: 1.8703 - val_accuracy: 0.2266 - lr: 0.0010

# %%
# Evaluation
import matplotlib.pyplot as plt

# Training and validation losses
plt.figure(figsize= (10,6))
plt.plot(history.history['loss'], label = "Training Loss")
plt.plot(history.history['val_loss'], label = "Validation Loss")
# Add a vertical line where the early stopping was triggered
stopped_epoch = len(history.history['loss'])-patience
plt.axvline(x=stopped_epoch, color='r', linestyle="-", label="Early Stopping (Best Epoch)")
plt.title("Training and validation losses")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred,axis=1)
y_true_classes = np.argmax(y_test, axis=1)

from sklearn.metrics import confusion_matrix
import seaborn as sns
# Confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(10,8))
sns.heatmap(
    conf_matrix,
    annot=True,          # Muestra los números en las celdas
    fmt='d',             # Formato entero
    cmap='Blues',        # Paleta de color
    xticklabels=label_encoder.classes_,  # nombres de clases
    yticklabels=label_encoder.classes_
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes,average="macro")
recall = recall_score(y_true_classes, y_pred_classes,average="macro")
f1 = f1_score(y_true_classes, y_pred_classes,average="macro")
print(accuracy)
print(precision)
print(recall)
print(f1)
# Out:
# 5/5 [==============================] - 1s 85ms/step
# 0.23417721518987342
# 0.196723108481142
# 0.23363629243563452
# 0.20203453344900713

# %%
# ROC curve and AUC
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Binarize tehe output (convert to one-hot)
n_classes = y_pred.shape[1]
y_test_bin = label_binarize(y_test, classes=np.arange(n_classes))

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:,i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and roc np.array_equal
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(),y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot
plt.figure(figsize=(8,6))
colors = [np.random.rand(3,) for i in range(n_classes)]

class_names = label_encoder.classes_

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i],color = colors[i], lw=2, label=(f"ROC curve of {class_names[i]} (AUC = {roc_auc[i]:0.2f})"))
plt.plot(fpr["micro"], tpr["micro"], label = f"micro-average ROC curve (AUC = {roc_auc['micro']:0.2f})", color = "deeppink", linestyle = ":", linewidth=4)
plt.plot([0,1],[0,1], 'k--', lw=2)
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()

# Plot the average AUC (one-vs-rest)
average_auc_ovr = np.mean(list(roc_auc[i] for i in range(n_classes)))
print(f"Average AUC (OvR): {average_auc_ovr:.2f}")
# Out:
# Average AUC (OvR): 0.71
